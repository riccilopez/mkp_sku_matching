# %% [markdown]
# # Product matching example

# %%
import re
import pandas as pd
import numpy as np
import pysnooper
from glob import glob
import time
from datetime import datetime
from pathlib import Path
import sys
from io import StringIO
import configparser

sys.path.append('..')
from modules.normalize_text import normalize_text
from modules.distance_metrics import levenshtein_and_dice_ratio, jaccard_distance

# %%
# %load_ext autoreload
# %autoreload 2

# %load_ext memory_profiler

# %% [markdown]
# ## Web Scrapping Catalog
#
# Scraped `csv` files are located in the `./scraped` directory.
# - Each file must contain the following three columns:
#     1. `Cadena`: Competitor's name
#     2. `SKU`: Name of the product, as shown in the competitor's web page
#     3. `Precio final`: Price of the product that will be used to compare against the matching ABI product.

# %%
df_scraping_dates.reset_index()
# Out:
#    index   datetime  str_date  week_num
# 0      1 2023-07-28  28-07-23        30
# 1      0 2023-08-04  04-08-23        31

# %%
num_date_to_process = 2

# %%
from azure.storage.blob import BlobServiceClient

# Define la conexión a tu cuenta de almacenamiento de Azure Blob
config = configparser.ConfigParser()
config.read('../azure_storage_conf.ini')

account_name = config['AzureBlobStorage']['account_name']
account_key  = config['AzureBlobStorage']['account_key']
blob_service_client = BlobServiceClient(
                        account_url = f"https://{account_name}.blob.core.windows.net", 
                        credential = account_key)

# Define la ruta de la carpeta dentro del contenedor
container_name = config['AzureBlobStorage']['container_name']
container_client = blob_service_client.get_container_client(container= container_name)


# Check avalaible dates
blob_files = list(container_client.list_blob_names())
available_dates = sorted(list(set([i[:8] for i in blob_files])))

# ***********************
# Añadido sólo para evitar errores en el formato de fecha
# TODO: Solicitar que el formato de fecha sea uniforme en todos los archivos
# df_scraping_dates = pd.to_datetime(available_dates, format = "%d-%m-%y").sort_values().to_frame(name = 'datetime')
available_dates_s = pd.Series(available_dates)
df_scraping_dates = pd.to_datetime(available_dates_s, 
                                   format = "%d-%m-%y", errors = 'coerce')\
                      .fillna(pd.to_datetime(available_dates_s, 
                                   format = "%Y-%m-%d", errors = 'coerce'))
df_scraping_dates = df_scraping_dates.sort_values().to_frame(name = 'datetime')
# ***********************

df_scraping_dates['str_date'] = df_scraping_dates['datetime'].dt.strftime("%d-%m-%y")
df_scraping_dates['week_num'] = df_scraping_dates['datetime'].dt.strftime("%U").apply(int)

# BLOB names
_, date_sf, week_num = df_scraping_dates.iloc[num_date_to_process - 1, :]
# blob_names = [i for i in blob_files if i.startswith(date_sf)]
blob_names = blob_files

#######
print(f'Scraping num > {num_date_to_process}')
print('Scripng date:', date_sf)
print('Week num:', week_num)
print('Num of files', len(blob_names))
# Out:
# Scraping num > 2
# Scripng date: 04-08-23
# Week num: 31
# Num of files 19

# %%
blob_files
# Out:
# ['2023-8-4-Azua.csv',
#  '2023-8-4-BodegasAlianza.csv',
#  '2023-8-4-CocaCola.csv',
#  '2023-8-4-Consuvino.csv',
#  '2023-8-4-Dislicores.csv',
#  '2023-8-4-FarmaTodo.csv',
#  '2023-8-4-Frubana.csv',
#  '2023-8-4-Garis.csv',
#  '2023-8-4-LaCastellana.csv',
#  '2023-8-4-LaEuropea.csv',
#  '2023-8-4-LaPlaya.csv',
#  '2023-8-4-LaRebajaVirtual.csv',
#  '2023-8-4-LaVioleta.csv',
#  '2023-8-4-MayoreoTotal.csv',
#  '2023-8-4-Scorpion.csv',
#  '2023-8-4-SuperMay.csv',
#  '2023-8-4-SurteTodo.csv',
#  '2023-8-4-SurtiTienda.csv',
#  '28-07-23-Alcca_MX.csv']

# %%
def get_csvs_from_blob(container_client, 
                       blob_name, encoding = 'utf-8'):
    blob_client = container_client.get_blob_client(blob_name)
    stream = blob_client.download_blob()
    data = stream.content_as_text(encoding = encoding)
    return StringIO(data)

# %%
b = blob_files[0]
_df = pd.read_csv(
               get_csvs_from_blob(container_client, 
                                  blob_name = b)
             )
_df
# Out:
#        type company      date country             site  \
# 0    Online    Azua  2023-8-4      MX  www.azua.com.mx
# 1    Online    Azua  2023-8-4      MX  www.azua.com.mx
# 2    Online    Azua  2023-8-4      MX  www.azua.com.mx
# 3    Online    Azua  2023-8-4      MX  www.azua.com.mx
# 4    Online    Azua  2023-8-4      MX  www.azua.com.mx
# ..      ...     ...       ...     ...              ...
# 124  Online    Azua  2023-8-4      MX  www.azua.com.mx
# 125  Online    Azua  2023-8-4      MX  www.azua.com.mx
# 126  Online    Azua  2023-8-4      MX  www.azua.com.mx
# 127  Online    Azua  2023-8-4      MX  www.azua.com.mx
# 128  Online    Azua  2023-8-4      MX  www.azua.com.mx
#
#                                                    url    zone  \
# 0    https://www.azua.com.mx/productos/marlboro-sum...  unique
# 1    https://www.azua.com.mx/productos/marlboro-roj...  unique
# 2    https://www.azua.com.mx/productos/pall-mall-to...  unique
# 3    https://www.azua.com.mx/productos/corona-light...  unique
# 4    https://www.azua.com.mx/productos/estrella-lat...  unique
# ..                                                 ...     ...
# 124  https://www.azua.com.mx/productos/pacifico-cla...  unique
# 125  https://www.azua.com.mx/productos/modelo-laton...  unique
# 126  https://www.azua.com.mx/productos/victoria-355...  unique
# 127  https://www.azua.com.mx/productos/michelob-vid...  unique
# 128  https://www.azua.com.mx/productos/victoria-che...  unique
#
#                                             price  \
# 0                                              68
# 1                                              75
# 2                                              68
# 3                   CORONA LIGHT LATA C/24 355 ML
# 4                      ESTRELLA LATON C/24 473 ML
# ..                                            ...
# 124               Pacífico clara Lata 355ml 24pzs
# 125                    Modelo laton 710 ml-12 pzs
# 126                     Victoria 355ml lata 24 Pz
# 127  MICHELOB VIDRIO 24 UDS 355 ML/ NO RETORNABLE
# 128            VICTORIA CHELADA LATON C/24 473 ML
#
#                                                   name  \
# 0                    Marlboro summer vista 1 cajetilla
# 1                            Marlboro rojo 1 cajetilla
# 2                        Pall mall Tokio (1 cajetilla)
# 3    //d3ugyf2ht6aenh.cloudfront.net/assets/themes/...
# 4    //d3ugyf2ht6aenh.cloudfront.net/assets/themes/...
# ..                                                 ...
# 124  //d3ugyf2ht6aenh.cloudfront.net/assets/themes/...
# 125  //d3ugyf2ht6aenh.cloudfront.net/assets/themes/...
# 126  //d3ugyf2ht6aenh.cloudfront.net/assets/themes/...
# 127  //d3ugyf2ht6aenh.cloudfront.net/assets/themes/...
# 128  //d3ugyf2ht6aenh.cloudfront.net/assets/themes/...
#
#                                                  url.1  image
# 0    //d3ugyf2ht6aenh.cloudfront.net/assets/themes/...    NaN
# 1    //d3ugyf2ht6aenh.cloudfront.net/assets/themes/...    NaN
# 2    //d3ugyf2ht6aenh.cloudfront.net/assets/themes/...    NaN
# 3                                                  350    NaN
# 4                                                  470    NaN
# ..                                                 ...    ...
# 124                                                380    NaN
# 125                                                319    NaN
# 126                                                380    NaN
# 127                                                418    NaN
# 128                                                568    NaN
#
# [129 rows x 11 columns]

# %%
_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129 entries, 0 to 128
# Data columns (total 11 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   type     129 non-null    object
#  1   company  129 non-null    object
#  2   date     129 non-null    object
#  3   country  129 non-null    object
#  4   site     129 non-null    object
#  5   url      129 non-null    object
#  6   zone     129 non-null    object
#  7   price    129 non-null    object
#  8   name     129 non-null    object
#  9   url.1    128 non-null    object
#  10  image    1 non-null      float64
# dtypes: float64(1), object(10)
# memory usage: 11.2+ KB

# %% [markdown]
# # Requerimientos
#
# 1. <mark>Nomenclatura uniforme de los archivos.</mark>
#     - `fecha_CompetidorName_PaisCode.csv`
#     - fecha formato `"dd-mm-yy"`
#     - Ejemplo:
#         - `04-08-23_Alcca_MX.csv`
#
#
# 2. <mark>Garantizar que la codificación (encoding) de los archivos sea la misma.</mark>
#     - "utf-8"
#     - `df.to_csv("file.csv", encoding="utf-8")`
#
#
# 3. <mark>Estructura uniforme de los archivos.</mark>
#     - Tener las mismas columnas (nombre y número) y orden en todos los archivos.
#     - Usar uno o más caracteres especiales como separador "`<sp>`"
#
#
# 4. <mark>En lo posible, dejar el campo de precio únicamente con valores numéricos.</mark>
#     - Quitar caractéres como "$", ",", etc.

# %% [markdown]
# ## ABI Marketplace Catalog

# %%
df_cat_precios_raw = pd.read_excel(
    '../abi_prices_catalogs/PreciosMarketplaceHistorico.xlsb', 
    sheet_name = 'PRECIOS', engine = 'pyxlsb', skiprows = 3)

print(df_cat_precios_raw.columns)

df_cat_precios = df_cat_precios_raw.copy()
# Sanity check
# Verify that there are no duplicated SKUs?
sku_colname   = 'SKU NUEVO'
sku_desc_name = 'DESCRIPCIÓN'
price_colname = f'PTR_W{15}'
brand_colname = 'Marca'

# Format the SKU material
df_cat_precios[sku_colname] = df_cat_precios[sku_colname]\
                               .apply(lambda x: str(int(x)))
assert not df_cat_precios[sku_colname].duplicated().any()

# Keep only useful columns and rename them
df_cat_precios = df_cat_precios[[sku_colname, sku_desc_name, price_colname, brand_colname]]
df_cat_precios['sku_name'] = df_cat_precios[sku_colname] + ' ' + df_cat_precios[brand_colname]
df_cat_precios = df_cat_precios[[sku_colname, sku_desc_name, price_colname]]
df_cat_precios.columns = ['sku', 'sku_name', 'price']

# Cleaning phase
# Lowercase string fields
df_cat_precios['sku_name_clean'] = df_cat_precios['sku_name']\
    .apply(lambda x: normalize_text(x, encode = 'ascii'))

df_cat_precios.head()
# Out:
# Index(['Categoría', 'SKU NUEVO', 'DESCRIPCIÓN', 'EAN/UPC', 'IMPERDIBLES',
#        'IVA', 'IEPS', 'Marca', 'DESCRIPCION_2', 'CUPO', 'PZA', 'PTR',
#        'PTR_UNITARIO', 'PTR_W1 ', 'PTR_W2', 'PTR_W3 ', 'PTR_W4', 'PTR_W5',
#        'PTR_W6', 'PTR_W7', 'PTR_W8', 'PTR_W9', 'PTR_W10', 'PTR_W11', 'PTR_W12',
#        'PTR_W13', 'PTR_W14', 'PTR_W15'],
#       dtype='object')
#        sku                         sku_name   price          sku_name_clean
# 0  3000200     NESTLE PUREZA VITAL 4L - 4PZ   65.84             npv 4lt 4pz
# 1  3006942        SANTA MARIA 355ML - 24PZS   76.00  santa maria 300ml 24pz
# 2  3000085  NESTLE PUREZA VITAL 1LT - 12PZS   82.00            npv 1lt 12pz
# 3  3001443            SANTA MARIA 1L -12PZS  100.00    santa maria 1lt 12pz
# 4  3000080         SANTA MARIA 1.5L - 12PZS  100.00  santa maria 1.5lt 12pz

# %% [markdown]
# # Start with the matching phase

# %%
def get_csvs_from_blob(container_client, 
                       blob_name, encoding = 'utf-8'):
    blob_client = container_client.get_blob_client(blob_name)
    stream = blob_client.download_blob()
    data = stream.content_as_text(encoding = encoding)
    return StringIO(data)

# %%
date = datetime.strptime(date_sf, "%d-%m-%y").strftime("%d%m%Y")

# scrap_files = glob(f'../scraped/{date}/*.csv')
col_price_name = 'Price'
col_competitor_name = 'Store'
col_sku_name = 'Category'
# Auxiliar cols (Just for Scorpio)
col_quantity = 'Quantity'
#col_desc = 'Description'
col_url = 'Url'

df_files = []
for b in blob_names:
    print(b)
    if ('_COL' in b) | ('LaRebaja' in b):
        print(f'\t{b} es de colombia')
        continue
    if 'Chedraui' in b:
        print('trying')
        _df = pd.read_csv(
               get_csvs_from_blob(container_client, 
                                  blob_name = b)#,
                                  #encoding = 'cp1252'),
               #encoding = 'cp1252', dtype=object#, sep = ";"
             )
    else:
        _df = pd.read_csv(
                  get_csvs_from_blob(container_client, 
                                     blob_name = b), dtype=object
              )
    # Save into the scraping output directory
    scraped_dir = f'../scraped/{date}'
    Path(scraped_dir).mkdir(exist_ok = True)
    _df.to_csv(f'{scraped_dir}/{b}', encoding = 'utf-8')
    if 'Chedraui' in b:
        if 'Estado' in _df.columns:
            _df = _df[_df['Estado'] == 'CDMX y area Metropolitana']
            _df['Store'] = 'Chedraui'
    if 'BodegaAurrera' in b:
        if 'Estado' in _df.columns:
            _df = _df[_df['Estado'] == 'Ciudad de Mexico']
            # Check for null prices:
            print('BA', _df['Price'].isnull().sum(), 'nulos')
            if _df['Price'].isnull().sum() > 100:
                _df['Price'] = _df['Unit_price']
                _df['Store'] = 'Bodega Aurrera'
    _df = _df[[col_competitor_name, 
              col_sku_name, 
              col_price_name,
              col_quantity,
              col_url
             ]]
    df_files.append(_df)

df_scrap = pd.concat(df_files)    
df_scrap['Category'] = df_scrap['Category'] + " " +\
                       df_scrap['Quantity'].fillna('') 
                       #+ " " + df_scrap['Description'].fillna('')
df_scrap.info()
# Out:
# 2023-8-4-Azua.csv
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-50-99dad3171b56> in <module>
#      49               col_price_name,
#      50               col_quantity,
# ---> 51               col_url
#      52              ]]
#      53     df_files.append(_df)
#
# ~/miniconda/envs/jup/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3462             if is_iterator(key):
#    3463                 key = list(key)
# -> 3464             indexer = self.loc._get_listlike_indexer(key, axis=1)[1]
#    3465
#    3466         # take() does not accept boolean indexers
#
# ~/miniconda/envs/jup/lib/python3.7/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis)
#    1312             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1313
# -> 1314         self._validate_read_indexer(keyarr, indexer, axis)
#    1315
#    1316         if needs_i8_conversion(ax.dtype) or isinstance(
#
# ~/miniconda/envs/jup/lib/python3.7/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis)
#    1372                 if use_interval_msg:
#    1373                     key = list(key)
# -> 1374                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1375
#    1376             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#
# KeyError: "None of [Index(['Store', 'Category', 'Price', 'Quantity', 'Url'], dtype='object')] are in the [columns]"

# %%
df_scrap['Store'].unique()
# Out:
# array(['Abarrotero', 'Alcca', 'Autoservicio la Playa', 'Alianza',
#        'Bodega Aurrera', 'Cava del Duero', 'Consuvino', 'Corpovino',
#        'Frubana', 'Ibarra Mayoreo', 'La Europea', 'Mayoreo Total',
#        'Scorpio', 'Soriana', 'Surtitienda', 'Walmart', 'La Castellana'],
#       dtype=object)

# %%
df_scrap['Category'].isnull().groupby(df_scrap['Store']).sum()
# Out:
# Store
# Abarrotero               0
# Alcca                    0
# Alianza                  0
# Autoservicio la Playa    0
# Bodega Aurrera           0
# Cava del Duero           0
# Consuvino                0
# Corpovino                0
# Frubana                  0
# Ibarra Mayoreo           0
# La Castellana            0
# La Europea               0
# Mayoreo Total            0
# Scorpio                  0
# Soriana                  0
# Surtitienda              0
# Walmart                  0
# Name: Category, dtype: int64

# %%
df_scrap.groupby('Store')['Store'].count()
# Out:
# Store
# Abarrotero                279
# Alcca                     599
# Alianza                   777
# Autoservicio la Playa     821
# Bodega Aurrera           1892
# Cava del Duero           1996
# Consuvino                1378
# Corpovino                 234
# Frubana                   110
# Ibarra Mayoreo           4550
# La Castellana            1028
# La Europea               1951
# Mayoreo Total            6249
# Scorpio                  4916
# Soriana                   267
# Surtitienda              2758
# Walmart                  1915
# Name: Store, dtype: int64

# %% [markdown]
# - The `Precio final` field is not homogeneous across the scraped `.csv` files.
# - A cleaning phase for the `Precio final` field is required.

# %%
date = datetime.strptime(date_sf, "%d-%m-%y").strftime("%d%m%Y")
# scrap_files = glob(f'../scraped/{date}/*.csv')
col_price_name      = 'Price'
col_competitor_name = 'Store'
col_sku_name        = 'Category'
# Auxiliar cols (Just for Scorpio)
col_quantity        = 'Quantity'
#col_desc = 'Description'
col_url  = 'Url'

# %%
# %%time
# Cleaning phase
def parse_price(x):
    s = re.sub('\"|\$|\,|[c/u]|[/u]', '', str(x)).strip()
    try:
        price = float(s)
    except ValueError as e:
        price = 0
    return price

cadenas = df_scrap[col_competitor_name].unique()
for cadena in cadenas:
    df_scrap.loc[df_scrap[col_competitor_name] == cadena, col_price_name] = \
        df_scrap.loc[df_scrap[col_competitor_name] == cadena, col_price_name]\
                .apply(parse_price)

# Cast columns
df_scrap['Price'] = df_scrap['Price'].astype(float)

# Cleaning phase
df_scrap['sku_name_clean'] = df_scrap[col_sku_name]\
    .apply(lambda x: normalize_text(x, encode = 'ascii'))
#df_scrap = df_scrap[~ df_scrap['Store'].isnull()]
df_scrap = df_scrap.reset_index(drop = True)
# Save the cleaned parquet
df_scrap.to_parquet(f'{scraped_dir}/{date}_scraped.parquet')
df_scrap.sample(10)
# Out:
# CPU times: user 28.2 s, sys: 1.72 s, total: 29.9 s
# Wall time: 30 s
#                 Store                                           Category  \
# 2121          Alianza                 Boligomas de Chamoy Alianza 250 g
# 2900   Bodega Aurrera  Aceite vegetal comestible Sabrosano +30  de so...
# 6613        Consuvino  Vino De Mesa Palacio de Bornos Frizzante Rosad...
# 28823         Walmart                  Vino Tinto Flor de Pingus 750 ml
# 28697     Surtitienda  Dulce Duvalin Avellana Vainilla 18 Piezas - Du...
# 2881   Bodega Aurrera           Manteca comestible Aurrera  mixta 500 g
# 2565   Bodega Aurrera                         Rompope La Holandesa  1 L
# 1896          Alianza  Whisky The Macallan 25 Years 700ml C/Estuche M...
# 28373     Surtitienda   Caramelo Montes Damy Con 100 Caramelos - Montes
# 25622         Scorpio  Yoghurt Danup Bebible Pina Coco 220 Gramos 5 P...
#
#          Price     Quantity  \
# 2121      61.0          NaN
# 2900      45.5          NaN
# 6613     239.0          NaN
# 28823   4059.0          NaN
# 28697     26.9          NaN
# 2881      35.0          NaN
# 2565     125.0          NaN
# 1896   52000.0          NaN
# 28373     54.6          NaN
# 25622     66.0  5 Pieza(s)
#
#                                                      Url  \
# 2121   https://www.bodegasalianza.com/gomitas-alianza...
# 2900   https://despensa.bodegaaurrera.com.mx/p/Aceite...
# 6613   https://www.consuvino.com.mx/product-page/pala...
# 28823  https://www.walmart.com.mx/cervezas-vinos-y-li...
# 28697  https://www.surtitienda.mx/dulce-duvalin-avell...
# 2881   https://despensa.bodegaaurrera.com.mx/p/Mantec...
# 2565   https://despensa.bodegaaurrera.com.mx/p/Rompop...
# 1896   https://www.bodegasalianza.com/whisky-the-maca...
# 28373  https://www.surtitienda.mx/caramelo-montes-dam...
# 25622  https://www.scorpion.com.mx/default/yoghurt-da...
#
#                                           sku_name_clean
# 2121                        boligoma chamoy alianza 200g
# 2900   aceite vegetal comestible sabrosano +30 soya c...
# 6613      vino mesa palacio borno frizzante rosado 700ml
# 28823                        vino tinto flor pingu 700ml
# 28697               dulce duvalin avellana vainilla 18pz
# 2881               manteca comestible aurrera mixta 500g
# 2565                               rompope holandesa 1lt
# 1896   whisky the macallan 25 years 700ml c estuche m...
# 28373                            caramelo monte damy 100
# 25622           yoghurt danup bebible pina coco 200g 5pz

# %%
df_scrap[df_scrap['Store'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Store, Category, Price, Quantity, Url, sku_name_clean]
# Index: []

# %%
df_scrap['Price'].isnull().groupby(df_scrap['Store']).sum()
# Out:
# Store
# Abarrotero               0
# Alcca                    3
# Alianza                  0
# Autoservicio la Playa    0
# Bodega Aurrera           0
# Cava del Duero           0
# Consuvino                0
# Corpovino                0
# Frubana                  0
# Ibarra Mayoreo           0
# La Castellana            0
# La Europea               0
# Mayoreo Total            0
# Scorpio                  0
# Soriana                  0
# Surtitienda              0
# Walmart                  0
# Name: Price, dtype: int64

# %%
df_scrap['Category'].isnull().groupby(df_scrap['Store']).sum()
# Out:
# Store
# Abarrotero               0
# Alcca                    0
# Alianza                  0
# Autoservicio la Playa    0
# Bodega Aurrera           0
# Cava del Duero           0
# Consuvino                0
# Corpovino                0
# Frubana                  0
# Ibarra Mayoreo           0
# La Castellana            0
# La Europea               0
# Mayoreo Total            0
# Scorpio                  0
# Soriana                  0
# Surtitienda              0
# Walmart                  0
# Name: Category, dtype: int64

# %%
df_scrap.groupby('Store')['Store'].count()
# Out:
# Store
# Abarrotero                279
# Alcca                     599
# Alianza                   777
# Autoservicio la Playa     821
# Bodega Aurrera           1892
# Cava del Duero           1996
# Consuvino                1378
# Corpovino                 234
# Frubana                   110
# Ibarra Mayoreo           4550
# La Castellana            1028
# La Europea               1951
# Mayoreo Total            6249
# Scorpio                  4916
# Soriana                   267
# Surtitienda              2758
# Walmart                  1915
# Name: Store, dtype: int64

# %%
df_scrap.shape
# Out:
# (31720, 6)

# %%
# Search for incorrect values
error_characters = df_scrap['Category'].apply(lambda x: '√' in str(x))
df_scrap[error_characters]
# Out:
# Empty DataFrame
# Columns: [Store, Category, Price, Quantity, Url, sku_name_clean]
# Index: []

# %%
df_scrap.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31720 entries, 0 to 31719
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Store           31720 non-null  object
#  1   Category        31720 non-null  object
#  2   Price           31717 non-null  float64
#  3   Quantity        15765 non-null  object
#  4   Url             31708 non-null  object
#  5   sku_name_clean  31720 non-null  object
# dtypes: float64(1), object(5)
# memory usage: 1.5+ MB

# %% [markdown]
# - There are some null values for `Precio Final`

# %%
# Are there missing values or 0 values in the price column?
_num_zero = df_scrap[df_scrap['Price'] <= 0].shape[0]
# Number of null values
_num_null = df_scrap['Price'].isnull().sum()
_total_to_omit = _num_zero + _num_null

print(f'There are {_num_zero} zero values and {_num_null} null values.\nTOTAL: {_total_to_omit} from a total of {df_scrap.shape[0]} ({(_total_to_omit / df_scrap.shape[0]) * 100 : .2f}% of values)')
# Out:
# There are 566 zero values and 3 null values.
# TOTAL: 569 from a total of 31720 ( 1.79% of values)

# %%
#df_scrap = df_scrap.drop(28466)

# %%
df_scrap['Price'].isnull().groupby([df_scrap.Store]).sum()
# Out:
# Store
# Abarrotero               0
# Alcca                    3
# Alianza                  0
# Autoservicio la Playa    0
# Bodega Aurrera           0
# Cava del Duero           0
# Consuvino                0
# Corpovino                0
# Frubana                  0
# Ibarra Mayoreo           0
# La Castellana            0
# La Europea               0
# Mayoreo Total            0
# Scorpio                  0
# Soriana                  0
# Surtitienda              0
# Walmart                  0
# Name: Price, dtype: int64

# %% [markdown]
# ### Drop null values and zero values for Price

# %%
df_scrap = df_scrap[~ df_scrap['Category'].isnull()]

# %%
df_scrap = df_scrap[df_scrap['Price'] > 0]
df_scrap = df_scrap[~ df_scrap['Price'].isnull()]
df_scrap.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 31151 entries, 0 to 31719
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Store           31151 non-null  object
#  1   Category        31151 non-null  object
#  2   Price           31151 non-null  float64
#  3   Quantity        15765 non-null  object
#  4   Url             31139 non-null  object
#  5   sku_name_clean  31151 non-null  object
# dtypes: float64(1), object(5)
# memory usage: 1.7+ MB

# %% [markdown]
# # Matching phase

# %% [markdown]
# ## Total Matching

# %%
# TEST: Combine Jaccard with Lev-Dice distances
def sku_name_conf(a, b) -> float:
    '''Ponderates Levenshtein-Dice distance with 
    Jaccard distances for unit matching'''
    lvd_conf = 1 - levenshtein_and_dice_ratio(a, b)
    jac_dist_units = jaccard_distance(a, b)
    return (lvd_conf) - (jac_dist_units * 0.1)

def exp_matching_value(x, a = 1.2):
    if x == 0:
        return x
    else:
        return np.exp(1 - (1/x**1.1))

def get_confidence(a, b):
    conf = sku_name_conf(a, b)
    conf = exp_matching_value(conf, a = 1.1)
    return round(conf, 2)

# %%
def get_performance(s1, s2):
    # Cleaning
    a1 = normalize_text(s1)
    a2 = normalize_text(s2)
    display(a1, a2)
    print()

    # Confidence using only LevDice
    lvd_conf = round(1 - levenshtein_and_dice_ratio(a1, a2), 2)
    jac_conf = round(1 - jaccard_distance(a1, a2), 2)
    comb_conf = get_confidence(a1, a2)
    display(lvd_conf, jac_conf, comb_conf)
    print()
    
    display(sku_name_conf(a1, a2))
    display(get_confidence(a1, a2))

    # Extract units
    b1 = extract_units(a1)
    b2 = extract_units(a2)
    display(b1, b2)
    print()

# %%
len(df_scrap[col_competitor_name].unique())
# Out:
# 17

# %%
df_scrap[col_competitor_name].unique()
# Out:
# array(['Abarrotero', 'Alcca', 'Autoservicio la Playa', 'Alianza',
#        'Bodega Aurrera', 'Cava del Duero', 'Consuvino', 'Corpovino',
#        'Frubana', 'Ibarra Mayoreo', 'La Europea', 'Mayoreo Total',
#        'Scorpio', 'Soriana', 'Surtitienda', 'Walmart', 'La Castellana'],
#       dtype=object)

# %%
# Total de evaluaciones
_n_evals = df_scrap.shape[0] * df_cat_precios.shape[0]
print(f'[{df_scrap.shape[0]:,} mkp skus] * {df_cat_precios.shape[0]:,}')
print(f'= {_n_evals:,} evaluations')

# SKUs Marketplace n
# SKUs scraping m

# ========
# n * m 
# =======
# Out:
# [31,151 mkp skus] * 247
# = 7,694,297 evaluations

# %%
col_competitor_name
# Out:
# 'Store'

# %%
# %%time
# %%memit
# # Mach every ABI SKU with every third-company sku

# __df_tgt    = df_scrap.copy()
# __df_ref    = df_cat_precios.copy()
# col_ref        = 'sku_name_clean'
# target_ref     = 'sku_name_clean'
# target_raw     = 'Category'
# conf_function  = get_confidence
# conf_threshold = 0.75

# # TODO: Vectorize implementation
# for c_num, cadena_name in enumerate(__df_tgt[col_competitor_name].unique()):
#     target_sku_names = []
#     distances        = []
#     prices           = []
#     urls = []
#     start_t = time.time()
#     for ref_sku in __df_ref[col_ref]:
#         __df_slice = __df_tgt[__df_tgt[col_competitor_name] == cadena_name].copy()
#         __df_slice['sku_ref'] = ref_sku
#         __df_slice['conf']    = __df_slice[[target_ref, 'sku_ref']]\
#                                 .apply(lambda x: 
#                                    get_confidence(x[target_ref], x['sku_ref']), 
#                                 axis = 1)
#         best_match = __df_slice.loc[__df_slice['conf'].idxmax()]
#         bm_conf = best_match['conf']
#         # If there are more than one matches a DataFrame will be returned
#         best_match = best_match.to_frame().transpose()
#         if bm_conf >= conf_threshold:
#             target_sku_names.append(best_match[target_raw].values[0])
#             distances.append(best_match['conf'].values[0])
#             prices.append(best_match[col_price_name].values[0])
#             urls.append(best_match[col_url].values[0])
#         else:
#             target_sku_names.append(np.nan)
#             distances.append(np.nan)
#             prices.append(np.nan)
#             urls.append(np.nan)
#     # Append the columns to the main dataframe
    
#     __df_ref[f'c_{cadena_name}_sku']   = target_sku_names
#     __df_ref[f'c_{cadena_name}_conf']  = distances
#     __df_ref[f'c_{cadena_name}_price'] = prices
#     __df_ref[f'c_{cadena_name}_url']   = urls
#     end_t = time.time()
#     print(f'{c_num}) {cadena_name} finished:\n\t' + 
#           f'{len(__df_slice)} skus evaluated. ' +
#           f'{end_t - start_t: .2f} seconds.' +
#           f'\n\t{np.sum(~np.isnan(prices))} matched.')

# %%
import concurrent.futures

__df_tgt = df_scrap.copy()
__df_ref = df_cat_precios.copy()
col_ref = 'sku_name_clean'
target_ref = 'sku_name_clean'
target_raw = 'Category'
conf_function = get_confidence
conf_threshold = 0.75
col_competitor_name = 'Store'

import concurrent.futures

# Define a helper function to process the slice for each cadena_name
def process_slice(cadena_name, 
                  col_competitor_name, col_ref, 
                  target_ref, conf_threshold, 
                  col_price_name, col_url, target_raw, 
                  __df_tgt, __df_ref):
    target_sku_names = []
    distances = []
    prices = []
    urls = []
    start_t = time.time()
    for ref_sku in __df_ref[col_ref]:
        __df_slice = __df_tgt[__df_tgt[col_competitor_name] == cadena_name].copy()
        __df_slice['sku_ref'] = ref_sku
        __df_slice['conf'] = __df_slice[[target_ref, 'sku_ref']] \
            .apply(lambda x: get_confidence(x[target_ref], x['sku_ref']),
                   axis=1)
        best_match = __df_slice.loc[__df_slice['conf'].idxmax()]
        bm_conf = best_match['conf']
        best_match = best_match.to_frame().transpose()
        if bm_conf >= conf_threshold:
            target_sku_names.append(best_match[target_raw].values[0])
            distances.append(best_match['conf'].values[0])
            prices.append(best_match[col_price_name].values[0])
            urls.append(best_match[col_url].values[0])
        else:
            target_sku_names.append(np.nan)
            distances.append(np.nan)
            prices.append(np.nan)
            urls.append(np.nan)
    return cadena_name, target_sku_names, distances,\
            prices, urls, time.time() - start_t,\
            np.sum(~np.isnan(prices)), __df_slice.shape[0]

# Define the main function for parallel execution
def parallel_process(__df_tgt, __df_ref, col_competitor_name, col_ref, target_ref, conf_threshold, col_price_name, col_url, target_raw):
    with concurrent.futures.ProcessPoolExecutor() as executor:
        results = []
        for c_num, cadena_name in enumerate(__df_tgt[col_competitor_name].unique()):
            result = executor.submit(process_slice, cadena_name, 
                                     col_competitor_name, col_ref, 
                                     target_ref, conf_threshold, 
                                     col_price_name, col_url, target_raw, 
                                     __df_tgt, __df_ref)
            results.append(result)
        for result in concurrent.futures.as_completed(results):
            cadena_name, target_sku_names, distances, prices, urls, elapsed_time, matched_count, num_skus_evaluated = result.result()
            __df_ref[f'c_{cadena_name}_sku']   = target_sku_names
            __df_ref[f'c_{cadena_name}_conf']  = distances
            __df_ref[f'c_{cadena_name}_price'] = prices
            __df_ref[f'c_{cadena_name}_url'] = urls
            print(f'{cadena_name} finished:\n\t{num_skus_evaluated} skus evaluated. {elapsed_time:.2f} seconds.\n\t{matched_count} matched.')

# Call the main function for parallel execution
parallel_process(__df_tgt, __df_ref, col_competitor_name, 
                 col_ref, target_ref, conf_threshold, 
                 col_price_name, col_url, target_raw)
# Out:
# Corpovino finished:
# 	234 skus evaluated. 22.07 seconds.
# 	26 matched.
# Abarrotero finished:
# 	279 skus evaluated. 26.02 seconds.
# 	12 matched.
# Frubana finished:
# 	110 skus evaluated. 12.29 seconds.
# 	12 matched.
# Alcca finished:
# 	596 skus evaluated. 53.45 seconds.
# 	31 matched.
# Alianza finished:
# 	751 skus evaluated. 67.79 seconds.
# 	32 matched.
# Autoservicio la Playa finished:
# 	821 skus evaluated. 73.35 seconds.
# 	36 matched.
# Soriana finished:
# 	267 skus evaluated. 25.90 seconds.
# 	26 matched.
# Consuvino finished:
# 	1378 skus evaluated. 121.81 seconds.
# 	57 matched.
# Bodega Aurrera finished:
# 	1892 skus evaluated. 167.47 seconds.
# 	69 matched.
# Cava del Duero finished:
# 	1996 skus evaluated. 176.51 seconds.
# 	51 matched.
# La Europea finished:
# 	1951 skus evaluated. 172.96 seconds.
# 	26 matched.
# La Castellana finished:
# 	1028 skus evaluated. 87.47 seconds.
# 	46 matched.
# Surtitienda finished:
# 	2218 skus evaluated. 183.67 seconds.
# 	57 matched.
# Walmart finished:
# 	1915 skus evaluated. 161.17 seconds.
# 	40 matched.
# Ibarra Mayoreo finished:
# 	4550 skus evaluated. 333.77 seconds.
# 	69 matched.
# Scorpio finished:
# 	4916 skus evaluated. 335.13 seconds.
# 	92 matched.
# Mayoreo Total finished:
# 	6249 skus evaluated. 415.55 seconds.
# 	105 matched.

# %%
__df_ref.columns = [c.replace('-', '').replace(' ', '_').replace('__', '_') for c in __df_ref.columns]
__df_ref.shape
# Out:
# (247, 72)

# %%
__df_ref
# Out:
#          sku                                 sku_name     price  \
# 0    3000200             NESTLE PUREZA VITAL 4L - 4PZ   65.8400
# 1    3006942                SANTA MARIA 355ML - 24PZS   76.0000
# 2    3000085          NESTLE PUREZA VITAL 1LT - 12PZS   82.0000
# 3    3001443                    SANTA MARIA 1L -12PZS  100.0000
# 4    3000080                 SANTA MARIA 1.5L - 12PZS  100.0000
# ..       ...                                      ...       ...
# 242  3009536               SOPA MARUCHAN RES - 12 PZS  155.0000
# 243  3009126  SOPA MARUCHAN CAMARON HABANERO - 12 PZS  162.0000
# 244  3009860                            TIEMPO - AIRE  100.0036
# 245  3010258                          TIEMPO - AIRE D  100.0000
# 246  3010687  SIM BUZZ MOVIL 7 DIAS SERV ILIM 10 PZS.   50.0000
#
#                               sku_name_clean c_Corpovino_sku  \
# 0                                npv 4lt 4pz             NaN
# 1                     santa maria 300ml 24pz             NaN
# 2                               npv 1lt 12pz             NaN
# 3                       santa maria 1lt 12pz             NaN
# 4                     santa maria 1.5lt 12pz             NaN
# ..                                       ...             ...
# 242                sopa maruchan 64g re 12pz             NaN
# 243  sopa maruchan 64g camaron habanero 12pz             NaN
# 244                              tiempo aire             NaN
# 245                              tiempo aire             NaN
# 246      sim buzz movil 7 dia serv ilim 10pz             NaN
#
#      c_Corpovino_conf  c_Corpovino_price c_Corpovino_url  \
# 0                 NaN                NaN             NaN
# 1                 NaN                NaN             NaN
# 2                 NaN                NaN             NaN
# 3                 NaN                NaN             NaN
# 4                 NaN                NaN             NaN
# ..                ...                ...             ...
# 242               NaN                NaN             NaN
# 243               NaN                NaN             NaN
# 244               NaN                NaN             NaN
# 245               NaN                NaN             NaN
# 246               NaN                NaN             NaN
#
#                                       c_Abarrotero_sku  c_Abarrotero_conf  \
# 0                                                  NaN                NaN
# 1                                                  NaN                NaN
# 2                                                  NaN                NaN
# 3                                                  NaN                NaN
# 4                                                  NaN                NaN
# ..                                                 ...                ...
# 242  Sopa Instantanea Sabor Carne de Res 64 g - caj...               0.91
# 243  Sopa Instantanea Camaron, Limon y Habanero 64 ...               0.91
# 244                                                NaN                NaN
# 245                                                NaN                NaN
# 246                                                NaN                NaN
#
#      ...  c_Ibarra_Mayoreo_price  \
# 0    ...                   123.7
# 1    ...                     NaN
# 2    ...                    90.0
# 3    ...                     NaN
# 4    ...                     NaN
# ..   ...                     ...
# 242  ...                   143.5
# 243  ...                   143.5
# 244  ...                     NaN
# 245  ...                     NaN
# 246  ...                     NaN
#
#                                   c_Ibarra_Mayoreo_url  \
# 0    https://ibarramayoreo.com/agua-natural-nestle-...
# 1                                                  NaN
# 2    https://ibarramayoreo.com/agua-natural-nestle-...
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 242   https://ibarramayoreo.com/sopa-maruchan-res-64-g
# 243  https://ibarramayoreo.com/sopa-maruchan-camaro...
# 244                                                NaN
# 245                                                NaN
# 246                                                NaN
#
#                                          c_Scorpio_sku  c_Scorpio_conf  \
# 0    Agua Natural Nestle Pureza Vital Botella 1 Lit...            0.82
# 1           Sta Maria Agua Natural 500 Ml 24 Pieza(s)             0.88
# 2    Agua Natural Nestle Pureza Vital Botella 1 Lit...            1.00
# 3                 Sta Maria Agua Natural 500 Ml Pieza             0.82
# 4                                                  NaN             NaN
# ..                                                 ...             ...
# 242  Sopa Instantanea Maruchan Pollo 64 Gramos 12 P...            0.85
# 243  Sopa Instantanea Maruchan Camaron Habanero 64 ...            1.00
# 244                                                NaN             NaN
# 245                                                NaN             NaN
# 246                                                NaN             NaN
#
#      c_Scorpio_price                                      c_Scorpio_url  \
# 0                9.0  https://www.scorpion.com.mx/default/agua-natur...
# 1                6.4  https://www.scorpion.com.mx/default/sta-maria-...
# 2               92.4  https://www.scorpion.com.mx/default/agua-natur...
# 3                6.9  https://www.scorpion.com.mx/default/sta-maria-...
# 4                NaN                                                NaN
# ..               ...                                                ...
# 242             13.7  https://www.scorpion.com.mx/default/sopa-insta...
# 243             13.7  https://www.scorpion.com.mx/default/sopa-insta...
# 244              NaN                                                NaN
# 245              NaN                                                NaN
# 246              NaN                                                NaN
#
#                                    c_Mayoreo_Total_sku  c_Mayoreo_Total_conf  \
# 0                                                  NaN                   NaN
# 1    Paquete agua Santa Maria 1L/12P 1 litro con 12...                  0.82
# 2                                                  NaN                   NaN
# 3    Paquete agua Santa Maria 1L/12P 1 litro con 12...                  1.00
# 4    Paquete agua Santa Maria 1L/12P 1 litro con 12...                  0.79
# ..                                                 ...                   ...
# 242  Caja Sopa Maruchan sabor a carne de res 12P/64...                  0.91
# 243  Caja sopa Maruchan sabor camaron con limon y c...                  0.92
# 244                                                NaN                   NaN
# 245                                                NaN                   NaN
# 246                                                NaN                   NaN
#
#      c_Mayoreo_Total_price                                c_Mayoreo_Total_url
# 0                      NaN                                                NaN
# 1                    139.0  https://www.mayoreototal.mx/products/paquete-a...
# 2                      NaN                                                NaN
# 3                    139.0  https://www.mayoreototal.mx/products/paquete-a...
# 4                    139.0  https://www.mayoreototal.mx/products/paquete-a...
# ..                     ...                                                ...
# 242                  207.0  https://www.mayoreototal.mx/products/sopa-maru...
# 243                  207.0  https://www.mayoreototal.mx/products/maruchan-...
# 244                    NaN                                                NaN
# 245                    NaN                                                NaN
# 246                    NaN                                                NaN
#
# [247 rows x 72 columns]

# %%
output_path = f'../outputs/{date}'
Path(output_path).mkdir(parents=True, exist_ok=True)
thr = 0.60
#                   .query(f'c_{seller}_conf > {thr}')\


__dfs = []
for seller in [c.replace('-', '').replace(' ', '_').replace('__', '_') for c in df_scrap[col_competitor_name].unique()]:
    a_cols = ['sku', 'sku_name', 'price']
    b_cols = [c for c in __df_ref.columns if f'c_{seller}' in c]

    __def2 = __df_ref[a_cols + b_cols]
    __def2 = __def2[__def2[f'c_{seller}_sku'].notnull()]\
                    .query('price > 0')\
                    .sort_values(f'c_{seller}_conf')
    __def2['price_diff'] = __def2['price'] - __def2[f'c_{seller}_price']
    __def2 = __def2.round(5)
    __def2.columns = ['mkp_sku_id', 
                      'mkp_sku_name', 
                      'mkp_price', 
                      'competitor_sku_name', 
                      '%_confidence', 
                      'competitor_price', 
                      'competitor_url',
                      'price_diff'
                      ]
    #__def2.to_csv(f'{output_path}/{seller}_top_{top}_matched.csv', index = False)
    __def2['competitor_name'] = seller
    __def2['%_price_diff'] = __def2['price_diff'] / __def2[f'mkp_price']
    __dfs.append(__def2)
    
cols =  ['competitor_name', 
         'mkp_sku_id', 'mkp_sku_name', 'mkp_price', 
         'competitor_sku_name', 'competitor_url', f'competitor_price', 
         'price_diff', '%_price_diff', '%_confidence']
last_df = pd.concat(__dfs)
last_df = last_df[cols]
last_df.competitor_url.fillna('Pending', inplace = True)
# Add scrapped date
last_df['scraping_date'] = pd.to_datetime(date, format = '%d%m%Y')

# total matches
print(last_df.shape)

last_df.to_csv(f'../outputs/{date}/Product_matching_MVP1_{date}.csv', index = False)
# Out:
# (787, 11)

# %%
__def2
# Out:
#     mkp_sku_id                                    mkp_sku_name   mkp_price  \
# 116    3009553          TEQUILA 100 ANOS REPOSADO 700ML - 1 PZ   170.00809
# 104    3009668                  BRANDY PRESIDIENTE 500ML - 1PZ    84.01903
# 109    3009669                  BRANDY PRESIDIENTE 900ML - 1PZ   141.52255
# 123    3009483                BRANDY PRESIDIENTE 200ML - 6 PZS   214.73305
# 96     3009551            BRANDY DON PEDRO CLASICO 200ML - 1PZ    37.59026
# 101    3009673            RON BACARDI CARTA BLANCA 200ML - 1PZ    49.99612
# 102    3009586         WHISKY JOHNNIE WALKER RED 200ML - 1 PZA    69.99811
# 108    3010273                   WHISKY PASSPORT 350 ML - 1 PZ   113.16125
# 113    3009554           TEQUILA CABRITO REPOSADO 750ML - 1 PZ   146.91794
# 127    3009787              Vodka Smirnoff No.21 1000 ml - 1pz   233.26196
# 156    3009789               Vodka Smirnoff No.21 750 ml - 1pz   167.31040
# 146    3009805        MAESTRO DOBEL TEQUILA DIAMANTE 700ML-1PZ   707.25780
# 150    3009790               Tequila Don Julio 70 700 ml - 1pz  1047.50471
# 122    3009779                     TORRES 5 BRANDY 700ML - 1PZ   205.25562
# 134    3009585                 TORRES 10 BRANDY 700 ML - 1 PZA   291.19144
# 112    3009809         CABRITO TEQ REPOSADO 950 +250 ML - 1 PZ   156.99881
# 147    3009803          JOSE CUERVO TEQ 1800 CRISTAL 700ML-1PZ   720.00086
# 139    3009781          JOSE CUERVO TEQUILA TRAD 950 ML - 1 PZ   339.99844
# 140    3009807          SAUZA HORNITOS TEQUILA REPOSADO 1L-1PZ   365.00537
# 151    3009793        HERRADURA ANTIGUO TEQ REPOSADO 950ML-1PZ   405.04486
# 148    3009794               Whisky Buchanan´s 12 750 ml - 1pz   798.99721
# 120    3009788        Vodka Smirnoff X1 Tamarindo 750 ml - 1pz   199.00832
# 154    3009783        JOSE CUERVO TEQUILA REPOSADO 695ML - 1PZ   258.99656
# 135    3009800          GRAN CENTENARIO AZUL TEQ REP 950ML-1PZ   260.00820
# 143    3009792         Tequila Don Julio Reposado 700 ml - 1pz   584.99183
# 141    3009802                   JACK DANIELS WHISKY 700ML-1PZ   380.00243
# 145    3009810           CHIVAS REGAL WHISKY 12 ANOS 750ML-1PZ   681.32797
# 149    3009786  Whisky Johnnie Walker Black Label 750 ml - 1pz   809.00708
# 144    3009791           Tequila Don Julio Blanco 700 ml - 1pz   612.99817
# 138    3009782        JOSE CUERVO TEQUILA TRAD PLATA 950ML-1PZ   328.95918
# 114    3009674            RON BACARDI CARTA BLANCA 750ML - 1PZ   167.00868
# 136    3009584    Whisky Johnnie Walker Red Label 700 ml - 1pz   298.00667
# 115    3009556        TEQUILA JOSE CUERVO ESPECIAL 695ML - 1PZ   168.60600
# 133    3009797            GRAN CENTENARO TEQUILA REP 950ML-1PZ   289.55862
# 132    3010274                     VODKA ABSOLUT 750 ML - 1 PZ   270.67475
# 131    3009799         GRAN CENTENARIO TEQUILA PLATA 700ML-1PZ   259.06756
# 130    3009795         CAZADORES TEQUILA REPOSADO 950 ML - 1PZ   258.99656
# 110    3009808             WILLIAM LAWSONS WHISKY 700 ML - 1PZ   141.00786
# 126    3009796        EL JIMADOR TEQUILA REPOSADO 700 ML - 1PZ   202.50468
# 125    3009780           JOSE CUERVO TEQUILA ESP 990 ML - 1 PZ   218.49563
# 121    3009578        BACARDI RON BLANCO  980 ML  -  1 BOTELLA   201.40430
# 119    3009557               Whisky Black & White 700 ml - 1pz   186.99293
# 118    3009555                    WHISKY PASSPORT 700ML - 1 PZ   177.32027
# 117    3010449                      AZTECA DE ORO 700 ML 1 PZA   172.84777
# 137    3009798         GRAN CENTENARIO TEQUILA PLATA 950ML-1PZ   302.46142
# 129    3009801           GRAN CENTENARIO TEQUILA REP 700ML-1PZ   260.00820
#
#                                   competitor_sku_name  %_confidence  \
# 116                   Tequila Patron Reposado 750 mL           0.78
# 104                          Brandy Presidente 700ml           0.80
# 109                          Brandy Presidente 700ml           0.80
# 123                          Brandy Presidente 700ml           0.80
# 96                   Brandy Don Pedro Clasico 750 mL           0.82
# 101                   Ron Bacardi Carta Blanca 980ml           0.82
# 102       Whisky Johnnie Walker Etiqueta Roja 700 ml           0.82
# 108                           Whisky Passport 700 mL           0.82
# 113                  Tequila Cabrito Reposado 950 mL           0.82
# 127                            Vodka Smirnoff 1000ml           0.88
# 156                            Vodka Smirnoff 750 mL           0.88
# 146  Tequila Maestro Tequilero Dobel Diamante 700 mL           0.89
# 150                   Tequila Don Julio Anejo 700 mL           0.89
# 122                      Brandy Torres 5 Anos 700 mL           0.89
# 134                          Brandy Torres 20 700 mL           0.91
# 112                  Tequila Cabrito Reposado 950 mL           0.91
# 147      Tequila Cuervo 1800 Cristalino Anejo 700 mL           0.91
# 139       Tequila Cuervo Tradicional Reposado 950 mL           0.91
# 140                   Tequila Sauza Hornitos 1000 mL           0.92
# 151                 Tequila Herradura Antiguo 950 mL           0.93
# 148                 Whisky Buchanan's 12 Anos 750 mL           0.93
# 120                  Vodka Smirnoff Tamarindo 750 mL           0.94
# 154                   Tequila Cuervo Especial 695 mL           0.94
# 135               Tequila Gran Centenario Azul 950ml           0.96
# 143                Tequila Don Julio Reposado 700 mL           1.00
# 141                       Whisky Jack Daniels 700 mL           1.00
# 145               Whisky Chivas Regal 12 Anos 750 ml           1.00
# 149      Whisky Johnnie Walker Etiqueta Negra 750 mL           1.00
# 144                  Tequila Don Julio Blanco 700 mL           1.00
# 138          Tequila Cuervo Tradicional Plata 950 mL           1.00
# 114                  Ron Bacardi Carta Blanca 750 mL           1.00
# 136       Whisky Johnnie Walker Etiqueta Roja 700 ml           1.00
# 115                   Tequila Cuervo Especial 695 mL           1.00
# 133          Tequila Gran Centenario Reposado 950 mL           1.00
# 132                             Vodka Absolut 750 mL           1.00
# 131             Tequila Gran Centenario Plata 700 mL           1.00
# 130                Tequila Cazadores Reposado 950 mL           1.00
# 110                    Whisky William Lawsons 700 Ml           1.00
# 126                   Tequila Jimador Reposado 700ml           1.00
# 125                    Tequila Cuervo Especial 990ml           1.00
# 121                   Ron Bacardi Carta Blanca 980ml           1.00
# 119                      Whisky Black & White 700 mL           1.00
# 118                           Whisky Passport 700 mL           1.00
# 117                      Brandy Azteca de Oro 700 mL           1.00
# 137             Tequila Gran Centenario Plata 950 ml           1.00
# 129           Tequila Gran Centenario Reposado 700ml           1.00
#
#      competitor_price                                     competitor_url  \
# 116            859.00  https://lacastellana.com/products/tequila-patr...
# 104            118.00  https://lacastellana.com/products/brandy-presi...
# 109            118.00  https://lacastellana.com/products/brandy-presi...
# 123            118.00  https://lacastellana.com/products/brandy-presi...
# 96             149.00  https://lacastellana.com/products/brandy-don-p...
# 101            299.00  https://lacastellana.com/products/ron-bacardi-...
# 102            375.00  https://lacastellana.com/products/whisky-johnn...
# 108            210.00  https://lacastellana.com/products/whisky-passport
# 113            157.00  https://lacastellana.com/products/tequila-cabr...
# 127            250.00  https://lacastellana.com/products/vodka-smirno...
# 156            205.00   https://lacastellana.com/products/vodka-smirnoff
# 146            756.00  https://lacastellana.com/products/tequila-maes...
# 150           1060.00  https://lacastellana.com/products/tequila-don-...
# 122            235.00  https://lacastellana.com/products/brandy-torre...
# 134           1160.00  https://lacastellana.com/products/brandy-torre...
# 112            157.00  https://lacastellana.com/products/tequila-cabr...
# 147            855.00  https://lacastellana.com/products/tequila-cuer...
# 139            419.00  https://lacastellana.com/products/tequila-cuer...
# 140            449.00  https://lacastellana.com/products/tequila-sauz...
# 151            459.00  https://lacastellana.com/products/tequila-herr...
# 148            945.00  https://lacastellana.com/products/whisky-bucha...
# 120            229.00  https://lacastellana.com/products/vodka-smirno...
# 154            210.00  https://lacastellana.com/products/tequila-cuer...
# 135            335.00  https://lacastellana.com/products/tequila-gran...
# 143            823.00  https://lacastellana.com/products/tequila-don-...
# 141            495.00  https://lacastellana.com/products/whisky-jack-...
# 145            855.33  https://lacastellana.com/products/whisky-chiva...
# 149           1045.00  https://lacastellana.com/products/whisky-johnn...
# 144            685.00  https://lacastellana.com/products/tequila-don-...
# 138            390.00  https://lacastellana.com/products/tequila-cuer...
# 114            245.00  https://lacastellana.com/products/ron-bacardi-...
# 136            375.00  https://lacastellana.com/products/whisky-johnn...
# 115            210.00  https://lacastellana.com/products/tequila-cuer...
# 133            363.00  https://lacastellana.com/products/tequila-gran...
# 132            317.88    https://lacastellana.com/products/vodka-absolut
# 131            304.00  https://lacastellana.com/products/tequila-gran...
# 130            409.00  https://lacastellana.com/products/tequila-caza...
# 110            225.00  https://lacastellana.com/products/whisky-willi...
# 126            285.00  https://lacastellana.com/products/tequila-jima...
# 125            269.00  https://lacastellana.com/products/tequila-cuer...
# 121            299.00  https://lacastellana.com/products/ron-bacardi-...
# 119            259.00  https://lacastellana.com/products/whisky-black...
# 118            210.00  https://lacastellana.com/products/whisky-passport
# 117            187.00  https://lacastellana.com/products/brandy-aztec...
# 137            354.00  https://lacastellana.com/products/tequila-gran...
# 129            299.00  https://lacastellana.com/products/tequila-gran...
#
#      price_diff competitor_name  %_price_diff
# 116  -688.99191   La_Castellana     -4.052701
# 104   -33.98097   La_Castellana     -0.404444
# 109    23.52255   La_Castellana      0.166211
# 123    96.73305   La_Castellana      0.450480
# 96   -111.40974   La_Castellana     -2.963793
# 101  -249.00388   La_Castellana     -4.980464
# 102  -305.00189   La_Castellana     -4.357288
# 108   -96.83875   La_Castellana     -0.855759
# 113   -10.08206   La_Castellana     -0.068624
# 127   -16.73804   La_Castellana     -0.071756
# 156   -37.68960   La_Castellana     -0.225268
# 146   -48.74220   La_Castellana     -0.068917
# 150   -12.49529   La_Castellana     -0.011929
# 122   -29.74438   La_Castellana     -0.144914
# 134  -868.80856   La_Castellana     -2.983634
# 112    -0.00119   La_Castellana     -0.000008
# 147  -134.99914   La_Castellana     -0.187499
# 139   -79.00156   La_Castellana     -0.232359
# 140   -83.99463   La_Castellana     -0.230119
# 151   -53.95514   La_Castellana     -0.133208
# 148  -146.00279   La_Castellana     -0.182733
# 120   -29.99168   La_Castellana     -0.150706
# 154    48.99656   La_Castellana      0.189178
# 135   -74.99180   La_Castellana     -0.288421
# 143  -238.00817   La_Castellana     -0.406857
# 141  -114.99757   La_Castellana     -0.302623
# 145  -174.00203   La_Castellana     -0.255387
# 149  -235.99292   La_Castellana     -0.291707
# 144   -72.00183   La_Castellana     -0.117458
# 138   -61.04082   La_Castellana     -0.185557
# 114   -77.99132   La_Castellana     -0.466990
# 136   -76.99333   La_Castellana     -0.258361
# 115   -41.39400   La_Castellana     -0.245507
# 133   -73.44138   La_Castellana     -0.253632
# 132   -47.20525   La_Castellana     -0.174398
# 131   -44.93244   La_Castellana     -0.173439
# 130  -150.00344   La_Castellana     -0.579172
# 110   -83.99214   La_Castellana     -0.595656
# 126   -82.49532   La_Castellana     -0.407375
# 125   -50.50437   La_Castellana     -0.231146
# 121   -97.59570   La_Castellana     -0.484576
# 119   -72.00707   La_Castellana     -0.385079
# 118   -32.67973   La_Castellana     -0.184298
# 117   -14.15223   La_Castellana     -0.081877
# 137   -51.53858   La_Castellana     -0.170397
# 129   -38.99180   La_Castellana     -0.149964
